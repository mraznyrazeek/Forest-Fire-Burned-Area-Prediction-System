# %% [markdown]
# # Machine Learning Model Training & Evaluation
#
# ## Objective
#
# The objective of this notebook is to train, compare, and evaluate multiple machine learning regression models for predicting the burned forest area.
#
# This notebook includes:
#
# - Loading the engineered dataset
# - Feature selection
# - Train-test split
# - Data preprocessing
# - Model training
# - Cross-validation
# - Hyperparameter tuning
# - Model evaluation
# - Model comparison
# - Saving the best-performing model

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import (
    train_test_split,
    cross_val_score,
    GridSearchCV
)

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

from sklearn.preprocessing import (
    StandardScaler,
    OneHotEncoder
)

from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

# Regression Models
from sklearn.linear_model import (
    LinearRegression,
    Ridge,
    Lasso
)

from sklearn.tree import DecisionTreeRegressor

from sklearn.ensemble import (
    RandomForestRegressor,
    GradientBoostingRegressor,
    ExtraTreesRegressor
)

import joblib

import warnings
warnings.filterwarnings("ignore")

print("Libraries imported successfully.")
# Out:
# Libraries imported successfully.

# %% [markdown]
# ### Load Engineered Dataset

# %%
df = pd.read_csv("../../dataset/forestfires_engineered.csv")

print(df.shape)

df.head()
# Out:
# (513, 26)
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  ...  dryness_index  \
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51  ...       0.157692
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33  ...       0.529412
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33  ...       0.429412
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97  ...       0.084694
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99  ...       0.114000
#
#    wind_effect  fuel_moisture_deficit month_num  month_sin     month_cos  \
# 0        54.94               0.503846         3   1.000000  6.123234e-17
# 1        16.20               1.041176        10  -0.866025  5.000000e-01
# 2        18.98               1.285294        10  -0.866025  5.000000e-01
# 3        33.20               0.339796         3   1.000000  6.123234e-17
# 4        20.52               0.513000         3   1.000000  6.123234e-17
#
#    day_num       day_sin   day_cos  location_cluster
# ...

# %% [markdown]
# ### Dataset Overview

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 513 entries, 0 to 512
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   X                      513 non-null    int64
#  1   Y                      513 non-null    int64
#  2   month                  513 non-null    str
#  3   day                    513 non-null    str
#  4   FFMC                   513 non-null    float64
#  5   DMC                    513 non-null    float64
#  6   DC                     513 non-null    float64
#  7   ISI                    513 non-null    float64
#  8   temp                   513 non-null    float64
#  9   RH                     513 non-null    int64
#  10  wind                   513 non-null    float64
#  11  rain                   513 non-null    float64
#  12  area                   513 non-null    float64
#  13  season                 513 non-null    str
#  14  rain_present           513 non-null    int64
# ...

# %%
df.describe()
# Out:
#                 X           Y        FFMC         DMC          DC         ISI  \
# count  513.000000  513.000000  513.000000  513.000000  513.000000  513.000000
# mean     4.678363    4.300195   90.637427  110.989279  549.155166    9.023587
# std      2.320059    1.230925    5.540920   64.191013  247.724594    4.575543
# min      1.000000    2.000000   18.700000    1.100000    7.900000    0.000000
# 25%      3.000000    4.000000   90.200000   68.600000  440.900000    6.400000
# 50%      4.000000    4.000000   91.600000  108.300000  664.500000    8.400000
# 75%      7.000000    5.000000   92.900000  142.400000  713.900000   11.000000
# max      9.000000    9.000000   96.200000  291.300000  860.600000   56.100000
#
#              temp          RH        wind        rain  ...  dryness_index  \
# count  513.000000  513.000000  513.000000  513.000000  ...     513.000000
# mean    18.887524   44.348928    4.010526    0.021832  ...       0.494685
# ...

# %% [markdown]
# ### Prepare Features and Target

# %%
# Create log-transformed target
df["target"] = np.log1p(df["area"])

X = df.drop(
    columns=[
        "area",
        "target",
        "month",
        "day",
        "season"
    ]
)

y = df["target"]

print("Feature Matrix:", X.shape)
print("Target:", y.shape)
# Out:
# Feature Matrix: (513, 22)
# Target: (513,)

# %% [markdown]
# ### Check Feature List

# %%
print(X.shape)

print(X.columns.tolist())
# Out:
# (513, 22)
# ['X', 'Y', 'FFMC', 'DMC', 'DC', 'ISI', 'temp', 'RH', 'wind', 'rain', 'rain_present', 'fire_weather_score', 'dryness_index', 'wind_effect', 'fuel_moisture_deficit', 'month_num', 'month_sin', 'month_cos', 'day_num', 'day_sin', 'day_cos', 'location_cluster']

# %% [markdown]
# # Feature Importance Analysis
#
# Before training multiple machine learning models, feature importance analysis is performed to understand which variables contribute the most to predicting burned area.
#
# A Random Forest Regressor is used because it naturally estimates the importance of each feature based on its contribution to reducing prediction error across many decision trees.

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(
    n_estimators=300,
    random_state=42
)

rf.fit(X, y)

importance = pd.DataFrame({
    "Feature": X.columns,
    "Importance": rf.feature_importances_
})

importance = importance.sort_values(
    by="Importance",
    ascending=False
)

importance.head(15)
# Out:
#                   Feature  Importance
# 6                    temp    0.108606
# 13            wind_effect    0.107632
# 14  fuel_moisture_deficit    0.096383
# 12          dryness_index    0.075423
# 7                      RH    0.063731
# 0                       X    0.060135
# 11     fire_weather_score    0.055145
# 3                     DMC    0.053623
# 4                      DC    0.051863
# 1                       Y    0.051646
# 5                     ISI    0.051419
# 2                    FFMC    0.049661
# 8                    wind    0.048217
# 19                day_sin    0.025808
# 21       location_cluster    0.024838

# %%
plt.figure(figsize=(10,8))

sns.barplot(
    data=importance.head(15),
    x="Importance",
    y="Feature"
)

plt.title("Top 15 Most Important Features")

plt.tight_layout()

plt.show()

# %% [markdown]
# ## Feature Importance Analysis
#
# A Random Forest Regressor was used to estimate the relative importance of each feature in predicting the burned forest area.
#
# ### Key Observations
#
# - **Temperature (`temp`)** is the most influential feature, indicating that higher temperatures have a strong impact on wildfire burned area.
# - **Wind Effect (`wind_effect`)** is the second most important feature, suggesting that the combination of wind speed and temperature plays a significant role in fire spread.
# - **Fuel Moisture Deficit (`fuel_moisture_deficit`)** and **Dryness Index (`dryness_index`)** are also among the top predictors, highlighting the importance of vegetation dryness and moisture conditions.
# - **Relative Humidity (`RH`)** contributes significantly, as lower humidity generally increases wildfire risk.
# - The engineered **Fire Weather Score (`fire_weather_score`)** ranks among the important predictors, confirming that combining multiple fire weather indices provides useful predictive information.
# - Spatial information, including **X**, **Y**, and **location_cluster**, also contributes to the prediction, indicating that wildfire behavior varies across different geographic regions.
#
# ### Conclusion
#
# The feature importance analysis shows that both the original meteorological variables and the engineered features contribute to the prediction of burned area. In particular, the engineered features rank among the most important predictors, demonstrating that feature engineering successfully enhanced the dataset and is expected to improve model performance.

# %% [markdown]
# # Train-Test Split
#
# The dataset is divided into training and testing sets using an 80:20 ratio.
#
# - **Training Set (80%)**: Used to train the machine learning models.
# - **Testing Set (20%)**: Used to evaluate model performance on unseen data.
#
# A fixed random state is used to ensure that the experiment is reproducible.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

print("Training Features :", X_train.shape)
print("Testing Features  :", X_test.shape)

print("Training Target   :", y_train.shape)
print("Testing Target    :", y_test.shape)
# Out:
# Training Features : (410, 22)
# Testing Features  : (103, 22)
# Training Target   : (410,)
# Testing Target    : (103,)

# %% [markdown]
# # Model Training and Comparison
#
# Multiple regression algorithms are trained and evaluated to determine the most suitable model for predicting burned forest area.
#
# The following models are compared:
#
# - Linear Regression
# - Ridge Regression
# - Lasso Regression
# - Decision Tree Regressor
# - Random Forest Regressor
# - Gradient Boosting Regressor
# - Extra Trees Regressor
#
# Each model is evaluated using:
#
# - Mean Absolute Error (MAE)
# - Root Mean Squared Error (RMSE)
# - R² Score
# - 5-Fold Cross Validation

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

from sklearn.model_selection import cross_val_score

# %% [markdown]
# ### Create Models

# %%
models = {

    "Linear Regression": Pipeline([
        ("scaler", StandardScaler()),
        ("model", LinearRegression())
    ]),

    "Ridge Regression": Pipeline([
        ("scaler", StandardScaler()),
        ("model", Ridge())
    ]),

    "Lasso Regression": Pipeline([
        ("scaler", StandardScaler()),
        ("model", Lasso())
    ]),

    "Decision Tree": DecisionTreeRegressor(
        random_state=42
    ),

    "Random Forest": RandomForestRegressor(
        n_estimators=300,
        random_state=42
    ),

    "Gradient Boosting": GradientBoostingRegressor(
        random_state=42
    ),

    "Extra Trees": ExtraTreesRegressor(
        n_estimators=300,
        random_state=42
    )
}

# %% [markdown]
# ### Train Every Model

# %%
results = []

for name, model in models.items():

    # Train
    model.fit(X_train, y_train)

    # Prediction
    prediction = model.predict(X_test)

    # Metrics
    mae = mean_absolute_error(y_test, prediction)

    rmse = np.sqrt(
        mean_squared_error(y_test, prediction)
    )

    r2 = r2_score(
        y_test,
        prediction
    )

    cv = cross_val_score(
        model,
        X_train,
        y_train,
        cv=5,
        scoring="r2"
    ).mean()

    results.append([
        name,
        mae,
        rmse,
        r2,
        cv
    ])

# %% [markdown]
# ### Create Comparison Table

# %%
results = pd.DataFrame(
    results,
    columns=[
        "Model",
        "MAE",
        "RMSE",
        "R² Score",
        "CV R²"
    ]
)

results = results.sort_values(
    by="R² Score",
    ascending=False
)

results
# Out:
#                Model       MAE      RMSE  R² Score     CV R²
# 2   Lasso Regression  1.139424  1.301170 -0.013462 -0.007659
# 1   Ridge Regression  1.089267  1.309388 -0.026304 -0.061811
# 0  Linear Regression  1.091308  1.313817 -0.033259 -0.066566
# 4      Random Forest  1.170498  1.363787 -0.113352 -0.141502
# 6        Extra Trees  1.164917  1.394811 -0.164582 -0.253188
# 5  Gradient Boosting  1.186691  1.477690 -0.307092 -0.209489
# 3      Decision Tree  1.425407  1.955132 -1.288187 -1.248425

# %%
plt.figure(figsize=(10,6))

sns.barplot(
    data=results,
    x="R² Score",
    y="Model"
)

plt.title("Model Comparison (R² Score)")


plt.show()

# %% [markdown]
# ## Initial Random Forest Evaluation

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(
    n_estimators=500,
    random_state=42
)

rf.fit(X_train, y_train)

print("Train R² :", rf.score(X_train, y_train))
print("Test R²  :", rf.score(X_test, y_test))
# Out:
# Train R² : 0.8408524803353634
# Test R²  : -0.111842627326596

# %% [markdown]
# ### Interpretation
#
# The baseline Random Forest model achieved a training R² score of **0.841** but a testing R² score of **-0.112**.
#
# The high training score indicates that the model learned the training data well. However, the negative testing R² score shows that it failed to generalize to unseen data and performed worse than predicting the average target value.
#
# This suggests that the baseline Random Forest model is overfitting the training data. Therefore, further model tuning and optimization are required to improve its generalization performance.

# %% [markdown]
# ## Hyperparameter Tuning (Random Forest)

# %% [markdown]
# Although Lasso Regression achieved the highest test R² among the baseline models, Random Forest was selected for hyperparameter tuning because ensemble tree-based methods are well suited for modelling complex nonlinear relationships in environmental data. Hyperparameter tuning reduced the Random Forest model's overfitting and improved its testing performance, although the overall predictive accuracy remained limited due to the highly skewed target variable and the large proportion of zero burned-area observations.

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    "n_estimators": [100, 300, 500],
    "max_depth": [None, 10, 20],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4]
}

# %%
rf = RandomForestRegressor(
    random_state=42
)

# %%
grid_search = GridSearchCV(
    estimator=rf,
    param_grid=param_grid,
    cv=5,
    scoring="r2",
    n_jobs=-1
)

grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [None, 10, 20],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 300, 500]},
#              scoring='r2')

# %%
print("Best Parameters:")
print(grid_search.best_params_)

print()

print("Best Cross Validation R²:")
print(grid_search.best_score_)
# Out:
# Best Parameters:
# {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 500}
#
# Best Cross Validation R²:
# -0.08478057416303444

# %%
best_rf = grid_search.best_estimator_

print("Train R² :", best_rf.score(X_train, y_train))
print("Test R²  :", best_rf.score(X_test, y_test))
# Out:
# Train R² : 0.5170320663586638
# Test R²  : -0.02926939954338814

# %% [markdown]
# ### Interpretation
#
# Hyperparameter tuning was applied using GridSearchCV to optimize the Random Forest model.
#
# The best model used the following parameters:
# - max_depth = 10
# - min_samples_split = 10
# - min_samples_leaf = 4
# - n_estimators = 500
#
# Compared to the baseline model, the tuned Random Forest reduced overfitting. The training R² score decreased from 0.841 to 0.517, while the testing R² score improved from -0.112 to -0.029. Although the model still did not achieve a positive R² score on the test data, the results indicate better generalization to unseen data.
#
# These findings suggest that hyperparameter tuning improved model stability, but predicting burned area remains challenging due to the highly skewed target distribution and the large number of zero burned-area observations in the dataset.

# %% [markdown]
# # Final Model Evaluation
#
# ## Actual vs Predicted Values
#
# The scatter plot compares the actual burned area values with the predictions generated by the tuned Random Forest model.
#
# A perfectly accurate model would produce points lying on the diagonal reference line.

# %%
# Predict using the tuned Random Forest model
y_pred = best_rf.predict(X_test)

# Calculate Test R²
test_r2 = best_rf.score(X_test, y_test)

plt.figure(figsize=(8, 8), dpi=120)

# Scatter plot
plt.scatter(
    y_test,
    y_pred,
    s=60,
    alpha=0.7,
    edgecolors="black",
    linewidth=0.6
)

# Perfect prediction line
plt.plot(
    [y_test.min(), y_test.max()],
    [y_test.min(), y_test.max()],
    color="red",
    linestyle="--",
    linewidth=2,
    label="Perfect Prediction"
)

# Display Test R² on the plot
plt.text(
    0.05,
    0.95,
    f"Test $R^2$ = {test_r2:.3f}",
    transform=plt.gca().transAxes,
    fontsize=11,
    verticalalignment="top",
    bbox=dict(
        facecolor="white",
        edgecolor="black",
        boxstyle="round,pad=0.4"
    )
)

plt.xlabel("Actual Burned Area (log1p)", fontsize=12)
plt.ylabel("Predicted Burned Area (log1p)", fontsize=12)
plt.title("Actual vs Predicted Burned Area", fontsize=14, fontweight="bold")

plt.legend()
plt.grid(True, linestyle="--", alpha=0.6)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Interpretation
#
# The Actual vs Predicted plot compares the observed burned area values with those predicted by the tuned Random Forest model.
#
# Ideally, all observations would lie on the red dashed diagonal line, indicating perfect agreement between actual and predicted values. However, many points are scattered away from the reference line, showing that the model struggles to accurately predict burned areas, particularly for larger fire events.
#
# This result is consistent with the negative test R² score and reflects the challenging characteristics of the Forest Fires dataset, including its highly skewed target distribution and the large proportion of zero burned-area observations.

# %% [markdown]
# ## Residual Analysis
#
# Residual analysis evaluates the prediction errors of the tuned Random Forest model by comparing the difference between the actual and predicted burned area values.

# %%
# Calculate residuals
residuals = y_test - y_pred

plt.figure(figsize=(9,6), dpi=120)

# Scatter plot
plt.scatter(
    y_pred,
    residuals,
    s=60,
    alpha=0.7,
    edgecolors="black",
    linewidth=0.6
)

# Zero reference line
plt.axhline(
    y=0,
    color="red",
    linestyle="--",
    linewidth=2,
    label="Zero Residual"
)

plt.xlabel("Predicted Burned Area (log1p)", fontsize=12)
plt.ylabel("Residuals", fontsize=12)
plt.title("Residual Plot", fontsize=14, fontweight="bold")

plt.legend()

plt.grid(True, linestyle="--", alpha=0.6)

plt.tight_layout()

plt.show()

# %% [markdown]
# ### Interpretation
#
# The residual plot illustrates the prediction errors of the tuned Random Forest model.
#
# Ideally, the residuals should be randomly distributed around the zero reference line without any visible pattern. Although many residuals are centered near zero, there is still considerable variation, particularly for observations with larger burned areas.
#
# A noticeable band of negative residuals is present because many records in the dataset have zero burned area, while the model predicts small positive values. This behaviour reflects the highly skewed nature of the Forest Fires dataset and contributes to the model's limited predictive performance.

# %% [markdown]
# ## Learning Curve
#
# The learning curve evaluates how the performance of the tuned Random Forest model changes as the amount of training data increases.

# %%
from sklearn.model_selection import learning_curve

train_sizes, train_scores, validation_scores = learning_curve(
    estimator=best_rf,
    X=X,
    y=y,
    cv=5,
    scoring="r2",
    train_sizes=np.linspace(0.1, 1.0, 10),
    n_jobs=-1,
    random_state=42
)

train_mean = train_scores.mean(axis=1)
validation_mean = validation_scores.mean(axis=1)

plt.figure(figsize=(9,6), dpi=120)

plt.plot(
    train_sizes,
    train_mean,
    marker="o",
    linewidth=2,
    label="Training Score"
)

plt.plot(
    train_sizes,
    validation_mean,
    marker="s",
    linewidth=2,
    label="Validation Score"
)

plt.xlabel("Training Samples", fontsize=12)
plt.ylabel("R² Score", fontsize=12)

plt.title(
    "Learning Curve of Tuned Random Forest",
    fontsize=14,
    fontweight="bold"
)

plt.legend()

plt.grid(True, linestyle="--", alpha=0.6)

plt.tight_layout()

plt.show()

# %% [markdown]
# ### Interpretation
#
# The learning curve illustrates the performance of the tuned Random Forest model as the training dataset increases.
#
# The training R² score gradually decreases and stabilizes around 0.54, indicating that the model becomes less overfitted as more training samples are introduced.
#
# The validation R² score improves steadily from approximately -0.85 to -0.22, suggesting that additional training data helps the model generalize better. However, the validation score remains below zero, indicating that the model still struggles to accurately predict unseen burned-area values.
#
# This behavior is mainly caused by the characteristics of the Forest Fires dataset, including the small dataset size, the high proportion of zero burned-area observations, and the highly skewed target distribution. Overall, the learning curve confirms that hyperparameter tuning reduced overfitting, but the predictive performance remains limited due to the dataset itself rather than the learning algorithm.

# %% [markdown]
# # Feature Importance Analysis
#
# Random Forest provides an estimate of how much each feature contributes to predicting the burned area. Features with higher importance values have a greater influence on the model's decisions.
#
# Visualizing feature importance helps identify the most influential meteorological and environmental factors associated with forest fire burned area.

# %%
importance = pd.DataFrame({
    "Feature": X.columns,
    "Importance": best_rf.feature_importances_
})

importance = importance.sort_values(
    by="Importance",
    ascending=False
)

importance.head(15)
# Out:
#                   Feature  Importance
# 13            wind_effect    0.114442
# 14  fuel_moisture_deficit    0.102549
# 6                    temp    0.092504
# 12          dryness_index    0.074880
# 11     fire_weather_score    0.070554
# 5                     ISI    0.065464
# 7                      RH    0.062615
# 8                    wind    0.056092
# 2                    FFMC    0.055135
# 0                       X    0.050738
# 3                     DMC    0.047911
# 4                      DC    0.043592
# 1                       Y    0.036214
# 21       location_cluster    0.036167
# 19                day_sin    0.029461

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,7))

sns.barplot(
    data=importance.head(15),
    x="Importance",
    y="Feature"
)

plt.title("Top 15 Most Important Features (Tuned Random Forest)")
plt.xlabel("Feature Importance")
plt.ylabel("Features")

plt.grid(axis="x", linestyle="--", alpha=0.4)

plt.show()

# %% [markdown]
# ### Interpretation
#
# The tuned Random Forest model identified wind effect as the most influential feature for predicting burned forest area, followed by fuel moisture deficit, temperature, dryness index, and fire weather score.
#
# These findings indicate that engineered meteorological features contributed more to the model's predictions than individual raw weather variables. This suggests that feature engineering successfully captured meaningful relationships between weather conditions and forest fire behavior.
#
# Traditional fire weather indices such as ISI, FFMC, DMC, and DC also contributed to the predictions, while spatial variables (X, Y, and location cluster) showed relatively lower importance. This implies that weather conditions had a greater influence on burned area prediction than geographical location within the dataset.
#
# Although the tuned Random Forest identified the most influential predictors, the overall predictive performance remained limited due to the highly skewed distribution of the target variable and the large proportion of zero burned-area observations in the dataset.

# %% [markdown]
# ## Save the Final Model

# %%
import joblib

joblib.dump(best_rf, "../models/random_forest_model.pkl")

joblib.dump(
    X.columns.tolist(),
    "../models/feature_names.pkl"
)

print("Model saved successfully!")
# Out:
# Model saved successfully!
